# %%
#A
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('jumlah_penderita_diabetes_jabar.csv')

# %%
df.head()
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0  1.0             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1  2.0             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2  3.0             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3  4.0             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4  5.0             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_penderita_dm satuan  tahun
# 0                57769  ORANG   2019
# 1               148447  ORANG   2019
# 2                12100  ORANG   2019
# 3                45412  ORANG   2019
# 4                    0  ORANG   2019
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.tail()
# Out:
#         id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 157  158.0             32    JAWA BARAT                 3275
# 158  159.0             32    JAWA BARAT                 3276
# 159  160.0             32    JAWA BARAT                 3277
# 160  161.0             32    JAWA BARAT                 3278
# 161  162.0             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 157         KOTA BEKASI                46481  ORANG   2024
# 158          KOTA DEPOK                44061  ORANG   2024
# 159         KOTA CIMAHI                10021  ORANG   2024
# 160    KOTA TASIKMALAYA                11782  ORANG   2024
# 161         KOTA BANJAR                 2415  ORANG   2024
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   162 non-null    float64
#  1   kode_provinsi        162 non-null    int64
#  2   nama_provinsi        162 non-null    object
#  3   kode_kabupaten_kota  162 non-null    int64
#  4   nama_kabupaten_kota  162 non-null    object
#  5   jumlah_penderita_dm  162 non-null    int64
#  6   satuan               162 non-null    object
#  7   tahun                162 non-null    int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 10.3+ KB
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data_numerik = df[['jumlah_penderita_dm', 'tahun']]
data_numerik.describe()
# Out:
#        jumlah_penderita_dm        tahun
# count           162.000000   162.000000
# mean          29699.388889  2021.500000
# std           31787.221502     1.713121
# min               0.000000  2019.000000
# 25%           12306.000000  2020.000000
# 50%           19279.000000  2021.500000
# 75%           39988.750000  2023.000000
# max          242169.000000  2024.000000
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data_unik = df['tahun'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data_unik = df['tahun'].unique()
#
# NameError: name 'df' is not defined
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
kota_unik = df['nama_kabupaten_kota'].unique()
len(kota_unik)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 kota_unik = df['nama_kabupaten_kota'].unique()
#       2 len(kota_unik)
#
# NameError: name 'df' is not defined
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df[['nama_kabupaten_kota', 'jumlah_penderita_dm', 'tahun']]
# Out:
#     nama_kabupaten_kota  jumlah_penderita_dm  tahun
# 0       KABUPATEN BOGOR                57769   2019
# 1    KABUPATEN SUKABUMI               148447   2019
# 2     KABUPATEN CIANJUR                12100   2019
# 3     KABUPATEN BANDUNG                45412   2019
# 4       KABUPATEN GARUT                    0   2019
# ..                  ...                  ...    ...
# 157         KOTA BEKASI                46481   2024
# 158          KOTA DEPOK                44061   2024
# 159         KOTA CIMAHI                10021   2024
# 160    KOTA TASIKMALAYA                11782   2024
# 161         KOTA BANJAR                 2415   2024
#
# [162 rows x 3 columns]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#B
df_2019 = df[df["tahun"] == 2019]
df_2019
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0    1.0             32    JAWA BARAT                 3201
# 1    2.0             32    JAWA BARAT                 3202
# 2    3.0             32    JAWA BARAT                 3203
# 3    4.0             32    JAWA BARAT                 3204
# 4    5.0             32    JAWA BARAT                 3205
# 5    6.0             32    JAWA BARAT                 3206
# 6    7.0             32    JAWA BARAT                 3207
# 7    8.0             32    JAWA BARAT                 3208
# 8    9.0             32    JAWA BARAT                 3209
# 9   10.0             32    JAWA BARAT                 3210
# 10  11.0             32    JAWA BARAT                 3211
# 11  12.0             32    JAWA BARAT                 3212
# 12  13.0             32    JAWA BARAT                 3213
# 13  14.0             32    JAWA BARAT                 3214
# 14  15.0             32    JAWA BARAT                 3215
# 15  16.0             32    JAWA BARAT                 3216
# 16  17.0             32    JAWA BARAT                 3217
# 17  18.0             32    JAWA BARAT                 3218
# 18  19.0             32    JAWA BARAT                 3271
# 19  20.0             32    JAWA BARAT                 3272
# 20  21.0             32    JAWA BARAT                 3273
# 21  22.0             32    JAWA BARAT                 3274
# 22  23.0             32    JAWA BARAT                 3275
# 23  24.0             32    JAWA BARAT                 3276
# 24  25.0             32    JAWA BARAT                 3277
# 25  26.0             32    JAWA BARAT                 3278
# 26  27.0             32    JAWA BARAT                 3279
#
#         nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun kategori_dm  \
# 0           KABUPATEN BOGOR                57769  ORANG   2019      Sedang
# 1        KABUPATEN SUKABUMI               148447  ORANG   2019      Tinggi
# 2         KABUPATEN CIANJUR                12100  ORANG   2019      Rendah
# 3         KABUPATEN BANDUNG                45412  ORANG   2019      Rendah
# 4           KABUPATEN GARUT                    0  ORANG   2019      Rendah
# 5     KABUPATEN TASIKMALAYA                10930  ORANG   2019      Rendah
# 6          KABUPATEN CIAMIS                69113  ORANG   2019      Sedang
# 7        KABUPATEN KUNINGAN                31582  ORANG   2019      Rendah
# 8         KABUPATEN CIREBON                21981  ORANG   2019      Rendah
# 9      KABUPATEN MAJALENGKA                12915  ORANG   2019      Rendah
# 10       KABUPATEN SUMEDANG                    0  ORANG   2019      Rendah
# 11      KABUPATEN INDRAMAYU                 5504  ORANG   2019      Rendah
# 12         KABUPATEN SUBANG                21691  ORANG   2019      Rendah
# 13     KABUPATEN PURWAKARTA                11783  ORANG   2019      Rendah
# 14       KABUPATEN KARAWANG               149537  ORANG   2019      Tinggi
# 15         KABUPATEN BEKASI                89055  ORANG   2019      Sedang
# 16  KABUPATEN BANDUNG BARAT                    0  ORANG   2019      Rendah
# 17    KABUPATEN PANGANDARAN                    0  ORANG   2019      Rendah
# 18               KOTA BOGOR                12273  ORANG   2019      Rendah
# 19            KOTA SUKABUMI                    0  ORANG   2019      Rendah
# 20             KOTA BANDUNG                45430  ORANG   2019      Rendah
# 21             KOTA CIREBON                    0  ORANG   2019      Rendah
# 22              KOTA BEKASI                42517  ORANG   2019      Rendah
# 23               KOTA DEPOK                48899  ORANG   2019      Rendah
# 24              KOTA CIMAHI                 9571  ORANG   2019      Rendah
# 25         KOTA TASIKMALAYA                    0  ORANG   2019      Rendah
# 26              KOTA BANJAR                 1946  ORANG   2019      Rendah
#
#     persentase_tahun
# 0           6.808729
# 1          17.496155
# 2           1.426122
# 3           5.352317
# 4           0.000000
# 5           1.288224
# 6           8.145747
# 7           3.722295
# 8           2.590709
# 9           1.522179
# 10          0.000000
# 11          0.648709
# 12          2.556529
# 13          1.388760
# 14         17.624624
# 15         10.496137
# 16          0.000000
# 17          0.000000
# 18          1.446512
# 19          0.000000
# 20          5.354438
# 21          0.000000
# 22          5.011108
# 23          5.763299
# 24          1.128050
# 25          0.000000
# 26          0.229358
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_gt_100k = df[df["jumlah_penderita_dm"] > 100000]
df_gt_100k
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 1    2.0             32    JAWA BARAT                 3202
# 14  15.0             32    JAWA BARAT                 3215
# 41  42.0             32    JAWA BARAT                 3215
# 42  43.0             32    JAWA BARAT                 3216
# 68  69.0             32    JAWA BARAT                 3215
#
#    nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 1   KABUPATEN SUKABUMI               148447  ORANG   2019
# 14  KABUPATEN KARAWANG               149537  ORANG   2019
# 41  KABUPATEN KARAWANG               139392  ORANG   2020
# 42    KABUPATEN BEKASI               242169  ORANG   2020
# 68  KABUPATEN KARAWANG               153547  ORANG   2021
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_sort_desc = df.sort_values("jumlah_penderita_dm", ascending=False)
df_sort_desc
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 42  43.0             32    JAWA BARAT                 3216
# 68  69.0             32    JAWA BARAT                 3215
# 14  15.0             32    JAWA BARAT                 3215
# 1    2.0             32    JAWA BARAT                 3202
# 41  42.0             32    JAWA BARAT                 3215
# ..   ...            ...           ...                  ...
# 19  20.0             32    JAWA BARAT                 3272
# 4    5.0             32    JAWA BARAT                 3205
# 10  11.0             32    JAWA BARAT                 3211
# 16  17.0             32    JAWA BARAT                 3217
# 17  18.0             32    JAWA BARAT                 3218
#
#         nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 42         KABUPATEN BEKASI               242169  ORANG   2020
# 68       KABUPATEN KARAWANG               153547  ORANG   2021
# 14       KABUPATEN KARAWANG               149537  ORANG   2019
# 1        KABUPATEN SUKABUMI               148447  ORANG   2019
# 41       KABUPATEN KARAWANG               139392  ORANG   2020
# ..                      ...                  ...    ...    ...
# 19            KOTA SUKABUMI                    0  ORANG   2019
# 4           KABUPATEN GARUT                    0  ORANG   2019
# 10       KABUPATEN SUMEDANG                    0  ORANG   2019
# 16  KABUPATEN BANDUNG BARAT                    0  ORANG   2019
# 17    KABUPATEN PANGANDARAN                    0  ORANG   2019
#
# [162 rows x 8 columns]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_sort_multi = df.sort_values(
    ["tahun", "jumlah_penderita_dm"],
    ascending=[True, False]  # tahun naik, jumlah turun
)
df_sort_multi
# Out:
#         id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 14    15.0             32    JAWA BARAT                 3215
# 1      2.0             32    JAWA BARAT                 3202
# 15    16.0             32    JAWA BARAT                 3216
# 6      7.0             32    JAWA BARAT                 3207
# 0      1.0             32    JAWA BARAT                 3201
# ..     ...            ...           ...                  ...
# 159  160.0             32    JAWA BARAT                 3277
# 156  157.0             32    JAWA BARAT                 3274
# 152  153.0             32    JAWA BARAT                 3218
# 154  155.0             32    JAWA BARAT                 3272
# 161  162.0             32    JAWA BARAT                 3279
#
#        nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 14      KABUPATEN KARAWANG               149537  ORANG   2019
# 1       KABUPATEN SUKABUMI               148447  ORANG   2019
# 15        KABUPATEN BEKASI                89055  ORANG   2019
# 6         KABUPATEN CIAMIS                69113  ORANG   2019
# 0          KABUPATEN BOGOR                57769  ORANG   2019
# ..                     ...                  ...    ...    ...
# 159            KOTA CIMAHI                10021  ORANG   2024
# 156           KOTA CIREBON                 9524  ORANG   2024
# 152  KABUPATEN PANGANDARAN                 7312  ORANG   2024
# 154          KOTA SUKABUMI                 5255  ORANG   2024
# 161            KOTA BANJAR                 2415  ORANG   2024
#
# [162 rows x 8 columns]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
top10_2019 = df[df["tahun"] == 2019] \
                .sort_values("jumlah_penderita_dm", ascending=False) \
                .head(10)
top10_2019
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 14  15.0             32    JAWA BARAT                 3215
# 1    2.0             32    JAWA BARAT                 3202
# 15  16.0             32    JAWA BARAT                 3216
# 6    7.0             32    JAWA BARAT                 3207
# 0    1.0             32    JAWA BARAT                 3201
# 23  24.0             32    JAWA BARAT                 3276
# 20  21.0             32    JAWA BARAT                 3273
# 3    4.0             32    JAWA BARAT                 3204
# 22  23.0             32    JAWA BARAT                 3275
# 7    8.0             32    JAWA BARAT                 3208
#
#    nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 14  KABUPATEN KARAWANG               149537  ORANG   2019
# 1   KABUPATEN SUKABUMI               148447  ORANG   2019
# 15    KABUPATEN BEKASI                89055  ORANG   2019
# 6     KABUPATEN CIAMIS                69113  ORANG   2019
# 0      KABUPATEN BOGOR                57769  ORANG   2019
# 23          KOTA DEPOK                48899  ORANG   2019
# 20        KOTA BANDUNG                45430  ORANG   2019
# 3    KABUPATEN BANDUNG                45412  ORANG   2019
# 22         KOTA BEKASI                42517  ORANG   2019
# 7   KABUPATEN KUNINGAN                31582  ORANG   2019
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_bogor = df[df["nama_kabupaten_kota"] == "KABUPATEN BOGOR"]
df_bogor
# Out:
#         id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1.0             32    JAWA BARAT                 3201
# 27    28.0             32    JAWA BARAT                 3201
# 54    55.0             32    JAWA BARAT                 3201
# 81    82.0             32    JAWA BARAT                 3201
# 108  109.0             32    JAWA BARAT                 3201
# 135  136.0             32    JAWA BARAT                 3201
#
#     nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun
# 0       KABUPATEN BOGOR                57769  ORANG   2019
# 27      KABUPATEN BOGOR                71462  ORANG   2020
# 54      KABUPATEN BOGOR                61139  ORANG   2021
# 81      KABUPATEN BOGOR                63978  ORANG   2022
# 108     KABUPATEN BOGOR                65620  ORANG   2023
# 135     KABUPATEN BOGOR                65751  ORANG   2024
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#C
#no 14
jumlah_penderitadm_per_tahun = df.groupby("tahun")["jumlah_penderita_dm"].sum()
jumlah_penderitadm_per_tahun
# Out:
# tahun
# 2019     848455
# 2020    1078857
# 2021     925675
# 2022     644704
# 2023     645390
# 2024     668220
# Name: jumlah_penderita_dm, dtype: int64
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#no 15
rata2_jumlah_penderitadm_tiap_kabupatenkota = df.groupby(['nama_kabupaten_kota'])[['jumlah_penderita_dm']].mean()
rata2_jumlah_penderitadm_tiap_kabupatenkota
# Out:
#                          jumlah_penderita_dm
# nama_kabupaten_kota
# KABUPATEN BANDUNG               51652.666667
# KABUPATEN BANDUNG BARAT         14246.333333
# KABUPATEN BEKASI                81174.333333
# KABUPATEN BOGOR                 64286.500000
# KABUPATEN CIAMIS                38304.000000
# KABUPATEN CIANJUR               14363.166667
# KABUPATEN CIREBON               20553.333333
# KABUPATEN GARUT                 20789.833333
# KABUPATEN INDRAMAYU             33056.666667
# KABUPATEN KARAWANG              92411.000000
# KABUPATEN KUNINGAN              21259.333333
# KABUPATEN MAJALENGKA            13028.333333
# KABUPATEN PANGANDARAN            7100.500000
# KABUPATEN PURWAKARTA            12953.500000
# KABUPATEN SUBANG                24120.166667
# KABUPATEN SUKABUMI              45277.500000
# KABUPATEN SUMEDANG              34894.000000
# KABUPATEN TASIKMALAYA           18176.333333
# KOTA BANDUNG                    43480.166667
# KOTA BANJAR                      3610.666667
# KOTA BEKASI                     45769.000000
# KOTA BOGOR                      17322.666667
# KOTA CIMAHI                      9817.166667
# KOTA CIREBON                    13126.166667
# KOTA DEPOK                      46105.000000
# KOTA SUKABUMI                    6139.166667
# KOTA TASIKMALAYA                 8866.000000
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#no 16
total_penderitadm_maxmin_per_tahun = total_kab = df.groupby(["nama_kabupaten_kota"])[["jumlah_penderita_dm"]].sum()
total_kab.idxmax(), total_kab.idxmin()
total_penderitadm_maxmin_per_tahun,total_kab
# Out:
# (                         jumlah_penderita_dm
#  nama_kabupaten_kota
#  KABUPATEN BANDUNG                     309916
#  KABUPATEN BANDUNG BARAT                85478
#  KABUPATEN BEKASI                      487046
#  KABUPATEN BOGOR                       385719
#  KABUPATEN CIAMIS                      229824
#  KABUPATEN CIANJUR                      86179
#  KABUPATEN CIREBON                     123320
#  KABUPATEN GARUT                       124739
#  KABUPATEN INDRAMAYU                   198340
#  KABUPATEN KARAWANG                    554466
#  KABUPATEN KUNINGAN                    127556
#  KABUPATEN MAJALENGKA                   78170
#  KABUPATEN PANGANDARAN                  42603
#  KABUPATEN PURWAKARTA                   77721
#  KABUPATEN SUBANG                      144721
#  KABUPATEN SUKABUMI                    271665
#  KABUPATEN SUMEDANG                    209364
#  KABUPATEN TASIKMALAYA                 109058
#  KOTA BANDUNG                          260881
#  KOTA BANJAR                            21664
#  KOTA BEKASI                           274614
#  KOTA BOGOR                            103936
#  KOTA CIMAHI                            58903
#  KOTA CIREBON                           78757
#  KOTA DEPOK                            276630
#  KOTA SUKABUMI                          36835
#  KOTA TASIKMALAYA                       53196,
#                           jumlah_penderita_dm
#  nama_kabupaten_kota
#  KABUPATEN BANDUNG                     309916
#  KABUPATEN BANDUNG BARAT                85478
#  KABUPATEN BEKASI                      487046
#  KABUPATEN BOGOR                       385719
#  KABUPATEN CIAMIS                      229824
#  KABUPATEN CIANJUR                      86179
#  KABUPATEN CIREBON                     123320
#  KABUPATEN GARUT                       124739
#  KABUPATEN INDRAMAYU                   198340
#  KABUPATEN KARAWANG                    554466
#  KABUPATEN KUNINGAN                    127556
#  KABUPATEN MAJALENGKA                   78170
#  KABUPATEN PANGANDARAN                  42603
#  KABUPATEN PURWAKARTA                   77721
#  KABUPATEN SUBANG                      144721
#  KABUPATEN SUKABUMI                    271665
#  KABUPATEN SUMEDANG                    209364
#  KABUPATEN TASIKMALAYA                 109058
#  KOTA BANDUNG                          260881
#  KOTA BANJAR                            21664
#  KOTA BEKASI                           274614
#  KOTA BOGOR                            103936
#  KOTA CIMAHI                            58903
#  KOTA CIREBON                           78757
#  KOTA DEPOK                            276630
#  KOTA SUKABUMI                          36835
#  KOTA TASIKMALAYA                       53196)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#no 17
kolom_kategoridm = {}
def kategori(x):
    if x < 50000: return "Rendah"
    elif x < 100000: return "Sedang"
    return "Tinggi"

df["kategori_dm"] = df["jumlah_penderita_dm"].apply(kategori)
df.head()
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0  1.0             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1  2.0             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2  3.0             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3  4.0             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4  5.0             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_penderita_dm satuan  tahun kategori_dm
# 0                57769  ORANG   2019      Sedang
# 1               148447  ORANG   2019      Tinggi
# 2                12100  ORANG   2019      Rendah
# 3                45412  ORANG   2019      Rendah
# 4                    0  ORANG   2019      Rendah
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#no 18
kolom_persentase_tahun = df['persentase_tahun'] = df['jumlah_penderita_dm'] / df.groupby('tahun')['jumlah_penderita_dm'].transform('sum') * 100
df.head()
# Out:
#     id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0  1.0             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1  2.0             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2  3.0             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3  4.0             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4  5.0             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_penderita_dm satuan  tahun kategori_dm  persentase_tahun
# 0                57769  ORANG   2019      Sedang          6.808729
# 1               148447  ORANG   2019      Tinggi         17.496155
# 2                12100  ORANG   2019      Rendah          1.426122
# 3                45412  ORANG   2019      Rendah          5.352317
# 4                    0  ORANG   2019      Rendah          0.000000
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#no 19
tabel_ringkas = df.groupby("tahun").agg(
 total_jumlah=('jumlah_penderita_dm','sum'),
 jumlah_kabupaten=('nama_kabupaten_kota','count')
)
tabel_ringkas
# Out:
#        total_jumlah  jumlah_kabupaten
# tahun
# 2019         848455                27
# 2020        1078857                27
# 2021         925675                27
# 2022         644704                27
# 2023         645390                27
# 2024         668220                27
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#D
df_2019 = df[df['tahun'] == 2019]

plt.figure(figsize=(12,6))
plt.bar(df_2019['nama_kabupaten_kota'], df_2019['jumlah_penderita_dm'])
plt.xticks(rotation=90)
plt.title('Jumlah Penderita DM per Kabupaten/Kota Tahun 2019')
plt.xlabel('Kabupaten/Kota')
plt.ylabel('Jumlah Penderita DM')
plt.tight_layout()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
total_per_year = df.groupby('tahun')['jumlah_penderita_dm'].sum().reset_index()

plt.figure(figsize=(7,4))
plt.plot(total_per_year['tahun'], total_per_year['jumlah_penderita_dm'], marker='o', linewidth=2)
plt.title('Total Jumlah Penderita DM Jawa Barat per Tahun')
plt.xlabel('Tahun')
plt.ylabel('Total Jumlah DM')
plt.grid(True)
plt.show()

total_per_year
# Out:
#    tahun  jumlah_penderita_dm
# 0   2019               848455
# 1   2020              1078857
# 2   2021               925675
# 3   2022               644704
# 4   2023               645390
# 5   2024               668220
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
top10_2019 = df_2019.sort_values('jumlah_penderita_dm', ascending=False).head(10)

plt.figure(figsize=(8,6))
plt.barh(top10_2019['nama_kabupaten_kota'], top10_2019['jumlah_penderita_dm'])
plt.gca().invert_yaxis()
plt.title('Top 10 Kabupaten/Kota Jumlah DM Tertinggi Tahun 2019')
plt.xlabel('Jumlah Penderita DM')
plt.ylabel('Kabupaten/Kota')
plt.tight_layout()
plt.show()

top10_2019
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 14  15.0             32    JAWA BARAT                 3215
# 1    2.0             32    JAWA BARAT                 3202
# 15  16.0             32    JAWA BARAT                 3216
# 6    7.0             32    JAWA BARAT                 3207
# 0    1.0             32    JAWA BARAT                 3201
# 23  24.0             32    JAWA BARAT                 3276
# 20  21.0             32    JAWA BARAT                 3273
# 3    4.0             32    JAWA BARAT                 3204
# 22  23.0             32    JAWA BARAT                 3275
# 7    8.0             32    JAWA BARAT                 3208
#
#    nama_kabupaten_kota  jumlah_penderita_dm satuan  tahun kategori_dm  \
# 14  KABUPATEN KARAWANG               149537  ORANG   2019      Tinggi
# 1   KABUPATEN SUKABUMI               148447  ORANG   2019      Tinggi
# 15    KABUPATEN BEKASI                89055  ORANG   2019      Sedang
# 6     KABUPATEN CIAMIS                69113  ORANG   2019      Sedang
# 0      KABUPATEN BOGOR                57769  ORANG   2019      Sedang
# 23          KOTA DEPOK                48899  ORANG   2019      Rendah
# 20        KOTA BANDUNG                45430  ORANG   2019      Rendah
# 3    KABUPATEN BANDUNG                45412  ORANG   2019      Rendah
# 22         KOTA BEKASI                42517  ORANG   2019      Rendah
# 7   KABUPATEN KUNINGAN                31582  ORANG   2019      Rendah
#
#     persentase_tahun
# 14         17.624624
# 1          17.496155
# 15         10.496137
# 6           8.145747
# 0           6.808729
# 23          5.763299
# 20          5.354438
# 3           5.352317
# 22          5.011108
# 7           3.722295
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def kategori(val):
    if val > 100000:
        return 'Tinggi'
    elif val >= 50000:
        return 'Sedang'
    return 'Rendah'
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_2019['kategori_dm'] = df_2019['jumlah_penderita_dm'].apply(kategori)

kategori_counts = df_2019['kategori_dm'].value_counts()
kategori_counts
# Out:
# C:\Users\aditya luthi\AppData\Local\Temp\ipykernel_22476\2321462848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['kategori_dm'] = df_2019['jumlah_penderita_dm'].apply(kategori)
# kategori_dm
# Rendah    22
# Sedang     3
# Tinggi     2
# Name: count, dtype: int64
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.figure(figsize=(6,6))
plt.pie(kategori_counts, labels=kategori_counts.index, autopct='%1.1f%%')
plt.title('Proporsi Kategori Penderita DM Tahun 2019')
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_2019[['nama_kabupaten_kota', 'jumlah_penderita_dm', 'kategori_dm']]
# Out:
#         nama_kabupaten_kota  jumlah_penderita_dm kategori_dm
# 0           KABUPATEN BOGOR                57769      Sedang
# 1        KABUPATEN SUKABUMI               148447      Tinggi
# 2         KABUPATEN CIANJUR                12100      Rendah
# 3         KABUPATEN BANDUNG                45412      Rendah
# 4           KABUPATEN GARUT                    0      Rendah
# 5     KABUPATEN TASIKMALAYA                10930      Rendah
# 6          KABUPATEN CIAMIS                69113      Sedang
# 7        KABUPATEN KUNINGAN                31582      Rendah
# 8         KABUPATEN CIREBON                21981      Rendah
# 9      KABUPATEN MAJALENGKA                12915      Rendah
# 10       KABUPATEN SUMEDANG                    0      Rendah
# 11      KABUPATEN INDRAMAYU                 5504      Rendah
# 12         KABUPATEN SUBANG                21691      Rendah
# 13     KABUPATEN PURWAKARTA                11783      Rendah
# 14       KABUPATEN KARAWANG               149537      Tinggi
# 15         KABUPATEN BEKASI                89055      Sedang
# 16  KABUPATEN BANDUNG BARAT                    0      Rendah
# 17    KABUPATEN PANGANDARAN                    0      Rendah
# 18               KOTA BOGOR                12273      Rendah
# 19            KOTA SUKABUMI                    0      Rendah
# 20             KOTA BANDUNG                45430      Rendah
# 21             KOTA CIREBON                    0      Rendah
# 22              KOTA BEKASI                42517      Rendah
# 23               KOTA DEPOK                48899      Rendah
# 24              KOTA CIMAHI                 9571      Rendah
# 25         KOTA TASIKMALAYA                    0      Rendah
# 26              KOTA BANJAR                 1946      Rendah
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.figure(figsize=(7,4))
plt.bar(total_per_tahun['tahun'], total_per_tahun['jumlah_penderita_dm'])
plt.title('Total Jumlah Penderita DM 2019–2022')
plt.xlabel('Tahun')
plt.ylabel('Total Penderita DM')
plt.show()

total_per_tahun
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 plt.figure(figsize=(7,4))
# ----> 2 plt.bar(total_per_tahun['tahun'], total_per_tahun['jumlah_penderita_dm'])
#       3 plt.title('Total Jumlah Penderita DM 2019–2022')
#       4 plt.xlabel('Tahun')
#
# NameError: name 'total_per_tahun' is not defined
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
terbanyak_tiap_tahun = df.loc[df.groupby('tahun')['jumlah_penderita_dm'].idxmax()][
    ['tahun','nama_kabupaten_kota','jumlah_penderita_dm']
]

terbanyak_tiap_tahun
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
kategori_summary = df_2019['kategori_dm'].value_counts().reset_index()
kategori_summary.columns = ['kategori', 'jumlah_kabupaten_kota']
kategori_summary
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
